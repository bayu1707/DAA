# %% [markdown]
# <a href="https://colab.research.google.com/github/bayu1707/DAA/blob/main/P4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

#Tentukan wilayah (domain) diagram Cartesian dan rasio lebar dan tinggi diagram
x = np.linspace(-4,4,10000)
plt.figure(figsize=(3,30))


#Gambar lingkarang kecil (titik) pada (0,0)
plt.plot(x, (0.01-x**2)**0.5, '-k')
plt.plot(x, -((0.01-x**2)**0.5), '-k')

#Tentukan persamaan matematika yang diinginkan
y = x - x - 0
y1 = x**3 - 2*x**2 - 5*x +6

plt.plot(x, y, '-k')

plt.plot(x, y1, '-r', label='y1')

plt.legend(loc='upper left')
plt.grid()
plt.show()
# Out:
# <ipython-input-1-5d6584ab7f30>:10: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, (0.01-x**2)**0.5, '-k')
# <ipython-input-1-5d6584ab7f30>:11: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -((0.01-x**2)**0.5), '-k')

# %%
import matplotlib.pyplot as plt
import numpy as np

#Tentukan wilayah (domain) diagram Cartesian dan rasio lebar dan tinggi diagram
x = np.linspace(-3,3,10000)
plt.figure(figsize=(3,30))


#Gambar lingkarang kecil (titik) pada (0,0)
plt.plot(x, (0.01-x**2)**0.5, '-k')
plt.plot(x, -((0.01-x**2)**0.5), '-k')

#Tentukan persamaan matematika yang diinginkan
y = x - x - 0
y1 = -(x**3 - 2*x**2 - x +2)

plt.plot(x, y, '-k')

plt.plot(x, y1, '-r', label='y1')

plt.legend(loc='upper left')
plt.grid()
plt.show()
# Out:
# <ipython-input-2-03a0a69f50e3>:10: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, (0.01-x**2)**0.5, '-k')
# <ipython-input-2-03a0a69f50e3>:11: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -((0.01-x**2)**0.5), '-k')

# %%
import matplotlib.pyplot as plt
import numpy as np

#Tentukan wilayah (domain) diagram Cartesian dan rasio lebar dan tinggi diagram
x = np.linspace(-8,8,10000)
plt.figure(figsize=(8,6.5))

#Tentukan persamaan matematika yang diinginkan
y = x -x -0
y1 = (4-x**2)**0.5
y2 = -(4-x**2)**0.5

y3 = 5 + (4-(x-5)**2)**0.5
y4 = 5 - (4-(x-5)**2)**0.5

y5 = -5 + (4-(x-5)**2)**0.5
y6 = -5 - (4-(x-5)**2)**0.5

y7 = 5 + (4-(x+5)**2)**0.5
y8 = 5 - (4-(x+5)**2)**0.5

y9 = -5 + (4-(x+5)**2)**0.5
y10 = -5 - (4-(x+5)**2)**0.5

plt.plot(x, y, '-k')
plt.plot(x, y1, '-r', label='y1, y2')
plt.plot(x, y2, '-r')
plt.plot(x, y3, '-g', label='y3, y4')
plt.plot(x, y4, '-g')
plt.plot(x, y5, '-b', label='y5, y6')
plt.plot(x, y6, '-b')
plt.plot(x, y7, '-y', label='y7, y8')
plt.plot(x, y8, '-y')
plt.plot(x, y9, '-y', label='y9, y10')
plt.plot(x, y10, '-y')

plt.legend(loc='upper center')
plt.grid()
plt.show()
# Out:
# <ipython-input-3-5e2d5e2e1e27>:10: RuntimeWarning: invalid value encountered in sqrt
#   y1 = (4-x**2)**0.5
# <ipython-input-3-5e2d5e2e1e27>:11: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(4-x**2)**0.5
# <ipython-input-3-5e2d5e2e1e27>:13: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 5 + (4-(x-5)**2)**0.5
# <ipython-input-3-5e2d5e2e1e27>:14: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 5 - (4-(x-5)**2)**0.5
# <ipython-input-3-5e2d5e2e1e27>:16: RuntimeWarning: invalid value encountered in sqrt
#   y5 = -5 + (4-(x-5)**2)**0.5
# <ipython-input-3-5e2d5e2e1e27>:17: RuntimeWarning: invalid value encountered in sqrt
#   y6 = -5 - (4-(x-5)**2)**0.5
# <ipython-input-3-5e2d5e2e1e27>:19: RuntimeWarning: invalid value encountered in sqrt
#   y7 = 5 + (4-(x+5)**2)**0.5
# <ipython-input-3-5e2d5e2e1e27>:20: RuntimeWarning: invalid value encountered in sqrt
#   y8 = 5 - (4-(x+5)**2)**0.5
# <ipython-input-3-5e2d5e2e1e27>:22: RuntimeWarning: invalid value encountered in sqrt
#   y9 = -5 + (4-(x+5)**2)**0.5
# <ipython-input-3-5e2d5e2e1e27>:23: RuntimeWarning: invalid value encountered in sqrt
#   y10 = -5 - (4-(x+5)**2)**0.5

# %%
import matplotlib.pyplot as plt
import numpy as np

#Tentukan wilayah (domain) diagram Cartesian dan rasio lebar dan tinggi diagram
x = np.linspace(-8,7,100000)
plt.figure(figsize=(9,5.5))

#Tentukan persamaan matematika yang diinginkan
y = x -x -0
y1 = (18-x**2)**0.5
y2 = -(18-x**2)**0.5

y3 = 4 + (4-(x-4.8)**2)**0.5
y4 = 4 - (4-(x-4.8)**2)**0.5

y7 = 4 + (4-(x+4.8)**2)**0.5
y8 = 4 - (4-(x+4.8)**2)**0.5

plt.plot(x, y1, '-k')
plt.plot(x, y2, '-k')
plt.plot(x, y3, '-k')
plt.plot(x, y4, '-k')
plt.plot(x, y7, '-k')
plt.plot(x, y8, '-k')

plt.legend(loc='upper center')
plt.grid()
plt.show()
# Out:
# <ipython-input-4-ddb9dbea80a9>:10: RuntimeWarning: invalid value encountered in sqrt
#   y1 = (18-x**2)**0.5
# <ipython-input-4-ddb9dbea80a9>:11: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(18-x**2)**0.5
# <ipython-input-4-ddb9dbea80a9>:13: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 4 + (4-(x-4.8)**2)**0.5
# <ipython-input-4-ddb9dbea80a9>:14: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 4 - (4-(x-4.8)**2)**0.5
# <ipython-input-4-ddb9dbea80a9>:16: RuntimeWarning: invalid value encountered in sqrt
#   y7 = 4 + (4-(x+4.8)**2)**0.5
# <ipython-input-4-ddb9dbea80a9>:17: RuntimeWarning: invalid value encountered in sqrt
#   y8 = 4 - (4-(x+4.8)**2)**0.5
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
